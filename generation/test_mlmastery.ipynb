# %% [markdown]
# Adapted from https://machinelearningmastery.com/how-to-develop-a-word-level-neural-language-model-in-keras/

# %%
import pandas as pd

# %%
import string
 
# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r',encoding='utf8')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text
 
# turn a doc into clean tokens
def clean_doc(doc):
    # replace '--' with a space ' '
    doc = doc.replace('--', ' ')
    # split into tokens by white space
    tokens = doc.split()
    # remove punctuation from each token
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # make lower case
    tokens = [word.lower() for word in tokens]
    return tokens
 
# save tokens to file, one dialog per line
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w',encoding='utf8')
    file.write(data)
    file.close()
 
# load document
in_filename = 'fake_news.txt'
doc = load_doc(in_filename)
print(doc[:200])
 
# clean document
tokens = clean_doc(doc)
print(tokens[:200])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
 
# organize into sequences of tokens
length = 50 + 1
sequences = list()
for i in range(length, len(tokens)):
    # select sequence of tokens
    seq = tokens[i-length:i]
    # convert into a line
    line = ' '.join(seq)
    # store
    sequences.append(line)
print('Total Sequences: %d' % len(sequences))
 
# save sequences to file
out_filename = 'fake_sequences.txt'
save_doc(sequences, out_filename)
# Out:
# and there it is michigan governor gretchen whitmer bans buying us flags during lockdown want is wrong with this woman
# said there is no game plan to distribute coronavirus vaccine is he right
# are you p
# ['and', 'there', 'it', 'is', 'michigan', 'governor', 'gretchen', 'whitmer', 'bans', 'buying', 'us', 'flags', 'during', 'lockdown', 'want', 'is', 'wrong', 'with', 'this', 'woman', 'said', 'there', 'is', 'no', 'game', 'plan', 'to', 'distribute', 'coronavirus', 'vaccine', 'is', 'he', 'right', 'are', 'you', 'panicking', 'about', 'enough', 'follow', 'our', 'guide', 'why', 'the', 'hiend', 'home', 'sales', 'market', 'is', 'immune', 'to', 'pandemic', 'conditions', 'realestate', 'tallahassee', 'coronavirus', 'was', 'produced', 'in', 'a', 'laboratory', 'former', 'cia', 'intel', 'officer', 'ahb', 'lmaoo', 'killin', 'me', 'here', 'in', 'other', 'news', 'im', 'immune', 'to', 'the', 'coronavirus', 'for', 'unknown', 'reasons', 'photos', 'show', 'part', 'of', 'huoshenshan', 'hospital', 'in', 'wuhan', 'built', 'in', 'five', 'days', 'you', 'said', 'drinking', 'alcohol', 'will', 'kill', 'the', 'coronavirus', 'i', 'mean', 'what', 'the', 'actual', 'fuck', 'is', 'wrong', 'with', 'you', 'americans', 'arm', 'themselves', 'as', 'coronavirus', 'panic', 'spreads', 'americans', 'coronavirus', 'coronavirus', 'contains', 'stoking', 'fears', 'over', 'artificially', 'created', 'bioweapon', 'the', 'media', 'pulled', 'down', 'an', 'entire', 'shelf', 'of', 'goods', 'so', 'that', 'they', 'can', 'present', 'the', 'news', 'of', 'people', 'buying', 'stuff', 'in', 'a', 'hysteria', 'over', 'the', 'coronavirus', 'chinese', 'health', 'authorities', 'confirm', 'patient', 'zero', 'had', 'sex', 'with', 'bats', 'lincoln', 'project', 'in', 'ring', 'any', 'bells', 'where', 'all', 'the', 'statistics', 'were', 'true', 'but', 'was', 'censored', 'by', 'facebook', 'because', 'it', 'said', 'bailed', 'out', 'wall', 'street', 'but', 'not', 'main', 'instead', 'of', 'bailed', 'out', 'wall', 'st', 'more', 'than', 'main', 'if']
# Total Tokens: 35148
# Unique Tokens: 5303
# Total Sequences: 35097

# %%
from numpy import array
from pickle import dump
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding

# load
# lines = pd.read_csv('fake_news.csv')['tweet'].values.tolist()

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r',encoding="utf8")
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text
 
# load
in_filename = 'fake_sequences.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')

# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)
# vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)
seq_length = X.shape[1]

# define model
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit model
model.fit(X, y, batch_size=128, epochs=100)

# save the model to file
model.save('model.h5')
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 50)            265200
#
#  lstm (LSTM)                 (None, 50, 100)           60400
#
#  lstm_1 (LSTM)               (None, 100)               80400
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 5304)              535704
#
# =================================================================
# Total params: 951,804
# Trainable params: 951,804
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 275/275 [==============================] - 9s 12ms/step - loss: 7.1150 - accuracy: 0.0378
# Epoch 2/100
# 275/275 [==============================] - 3s 11ms/step - loss: 6.7074 - accuracy: 0.0411
# Epoch 3/100
# 275/275 [==============================] - 3s 11ms/step - loss: 6.4750 - accuracy: 0.0490
# Epoch 4/100
# 275/275 [==============================] - 3s 11ms/step - loss: 6.1530 - accuracy: 0.0587
# Epoch 5/100
# 275/275 [==============================] - 3s 11ms/step - loss: 5.8979 - accuracy: 0.0757
# Epoch 6/100
# 275/275 [==============================] - 3s 11ms/step - loss: 5.6431 - accuracy: 0.1060
# Epoch 7/100
# 275/275 [==============================] - 3s 11ms/step - loss: 5.4432 - accuracy: 0.1390
# Epoch 8/100
# 275/275 [==============================] - 3s 11ms/step - loss: 5.2802 - accuracy: 0.1676
# Epoch 9/100
# 275/275 [==============================] - 3s 11ms/step - loss: 5.3413 - accuracy: 0.1509
# Epoch 10/100
# 275/275 [==============================] - 3s 11ms/step - loss: 5.0136 - accuracy: 0.2095
# Epoch 11/100
# 275/275 [==============================] - 3s 11ms/step - loss: 4.8156 - accuracy: 0.2384
# Epoch 12/100
# 275/275 [==============================] - 3s 11ms/step - loss: 4.6554 - accuracy: 0.2544
# Epoch 13/100
# 275/275 [==============================] - 3s 11ms/step - loss: 4.5159 - accuracy: 0.2656
# Epoch 14/100
# 275/275 [==============================] - 3s 11ms/step - loss: 4.3841 - accuracy: 0.2766
# Epoch 15/100
# 275/275 [==============================] - 3s 11ms/step - loss: 4.2624 - accuracy: 0.2855
# Epoch 16/100
# 275/275 [==============================] - 3s 11ms/step - loss: 4.1412 - accuracy: 0.2949
# Epoch 17/100
# 275/275 [==============================] - 3s 11ms/step - loss: 4.0282 - accuracy: 0.3032
# Epoch 18/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.9120 - accuracy: 0.3119
# Epoch 19/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.8192 - accuracy: 0.3180
# Epoch 20/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.7249 - accuracy: 0.3277
# Epoch 21/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.6257 - accuracy: 0.3353
# Epoch 22/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.5236 - accuracy: 0.3439
# Epoch 23/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.4315 - accuracy: 0.3513
# Epoch 24/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.3346 - accuracy: 0.3617
# Epoch 25/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.2404 - accuracy: 0.3730
# Epoch 26/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.1509 - accuracy: 0.3842
# Epoch 27/100
# 275/275 [==============================] - 3s 12ms/step - loss: 3.0614 - accuracy: 0.3961
# Epoch 28/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.9725 - accuracy: 0.4081
# Epoch 29/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.9584 - accuracy: 0.4136
# Epoch 30/100
# 275/275 [==============================] - 3s 11ms/step - loss: 3.0059 - accuracy: 0.4056
# Epoch 31/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.8436 - accuracy: 0.4291
# Epoch 32/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.7780 - accuracy: 0.4386
# Epoch 33/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.7045 - accuracy: 0.4485
# Epoch 34/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.7048 - accuracy: 0.4501
# Epoch 35/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.7726 - accuracy: 0.4388
# Epoch 36/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.7941 - accuracy: 0.4337
# Epoch 37/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.6182 - accuracy: 0.4599
# Epoch 38/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.6217 - accuracy: 0.4593
# Epoch 39/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.7218 - accuracy: 0.4434
# Epoch 40/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.6185 - accuracy: 0.4598
# Epoch 41/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.5349 - accuracy: 0.4732
# Epoch 42/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.4539 - accuracy: 0.4881
# Epoch 43/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.3794 - accuracy: 0.4964
# Epoch 44/100
# 275/275 [==============================] - 3s 12ms/step - loss: 2.3061 - accuracy: 0.5113
# Epoch 45/100
# 275/275 [==============================] - 3s 12ms/step - loss: 2.2383 - accuracy: 0.5227
# Epoch 46/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.1758 - accuracy: 0.5339
# Epoch 47/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.1299 - accuracy: 0.5426
# Epoch 48/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.0994 - accuracy: 0.5469
# Epoch 49/100
# 275/275 [==============================] - 3s 11ms/step - loss: 2.0494 - accuracy: 0.5562
# Epoch 50/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.9910 - accuracy: 0.5661
# Epoch 51/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.9439 - accuracy: 0.5761
# Epoch 52/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.8999 - accuracy: 0.5827
# Epoch 53/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.8550 - accuracy: 0.5916
# Epoch 54/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.8323 - accuracy: 0.5944
# Epoch 55/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.8249 - accuracy: 0.5951
# Epoch 56/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.8087 - accuracy: 0.5998
# Epoch 57/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.8090 - accuracy: 0.5955
# Epoch 58/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.7210 - accuracy: 0.6142
# Epoch 59/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.6628 - accuracy: 0.6252
# Epoch 60/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.6155 - accuracy: 0.6358
# Epoch 61/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.5918 - accuracy: 0.6406
# Epoch 62/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.5464 - accuracy: 0.6483
# Epoch 63/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.5118 - accuracy: 0.6583
# Epoch 64/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.4855 - accuracy: 0.6628
# Epoch 65/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.4646 - accuracy: 0.6656
# Epoch 66/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.4416 - accuracy: 0.6697
# Epoch 67/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.4391 - accuracy: 0.6724
# Epoch 68/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.5902 - accuracy: 0.6409
# Epoch 69/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.6319 - accuracy: 0.6318
# Epoch 70/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.5302 - accuracy: 0.6526
# Epoch 71/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.4936 - accuracy: 0.6629
# Epoch 72/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.4018 - accuracy: 0.6787
# Epoch 73/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.3854 - accuracy: 0.6838
# Epoch 74/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.4129 - accuracy: 0.6780
# Epoch 75/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.6844 - accuracy: 0.6245
# Epoch 76/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.7333 - accuracy: 0.6090
# Epoch 77/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.5872 - accuracy: 0.6392
# Epoch 78/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.5162 - accuracy: 0.6547
# Epoch 79/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.4627 - accuracy: 0.6660
# Epoch 80/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.4258 - accuracy: 0.6757
# Epoch 81/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.3877 - accuracy: 0.6830
# Epoch 82/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.3482 - accuracy: 0.6908
# Epoch 83/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.3248 - accuracy: 0.6956
# Epoch 84/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.2997 - accuracy: 0.6991
# Epoch 85/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.2699 - accuracy: 0.7071
# Epoch 86/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.2414 - accuracy: 0.7128
# Epoch 87/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.2161 - accuracy: 0.7183
# Epoch 88/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.1900 - accuracy: 0.7235
# Epoch 89/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.1642 - accuracy: 0.7284
# Epoch 90/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.1432 - accuracy: 0.7338
# Epoch 91/100
# 275/275 [==============================] - 3s 12ms/step - loss: 1.1176 - accuracy: 0.7382
# Epoch 92/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.1000 - accuracy: 0.7436
# Epoch 93/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.0723 - accuracy: 0.7518
# Epoch 94/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.0534 - accuracy: 0.7536
# Epoch 95/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.0294 - accuracy: 0.7583
# Epoch 96/100
# 275/275 [==============================] - 3s 11ms/step - loss: 1.0132 - accuracy: 0.7628
# Epoch 97/100
# 275/275 [==============================] - 3s 11ms/step - loss: 0.9906 - accuracy: 0.7681
# Epoch 98/100
# 275/275 [==============================] - 3s 11ms/step - loss: 0.9679 - accuracy: 0.7726
# Epoch 99/100
# 275/275 [==============================] - 3s 11ms/step - loss: 0.9494 - accuracy: 0.7766
# Epoch 100/100
# 275/275 [==============================] - 3s 11ms/step - loss: 0.9608 - accuracy: 0.7716

# %%
from random import randint
from pickle import load
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r',encoding='utf8')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# generate a sequence from a language model
def generate_seq(model, tokenizer, seq_length, seed_text, n_words):
    result = list()
    in_text = seed_text
    # generate a fixed number of words
    for _ in range(n_words):
    # encode the text as integer
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        # truncate sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        # predict probabilities for each word
        #yhat = model.predict_classes(encoded, verbose=0)
        yhat = np.argmax(model.predict(encoded), axis=-1)
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
        # append to input
        in_text += ' ' + out_word
        result.append(out_word)
    return ' '.join(result)

# load cleaned text sequences
in_filename = 'fake_sequences.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')
seq_length = len(lines[0].split()) - 1

# load the model
model = load_model('model.h5')

# load the tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))

for k in range(10):
    print(f'Text {k+1}')
    # select a seed text
    print('Seed')
    seed_text = lines[randint(0,len(lines))]
    print(seed_text + '\n')

    # generate new text
    generated = generate_seq(model, tokenizer, seq_length, seed_text, 50)
    print('Generated')
    print(generated)
    print('--------------------------------------------------------------------------------')
# Out:
# Text 1
# real government planned agendas italy did not follow who protocol and did an autopsy on a corpse that died from and realised that coronavirus is actually not a virus but a bacterium which gets amplified with electromagnetic radiation that also produces inflammation and hypoxia and multiple other claims coronavirus bioweapon how
#
# Generated
# china stole coronavirus from canada and weaponized it via coronaviruschina may god save us from china parentodo tras leer lo siguiente hacemos una consulta a mano alzada hay que reír belgium health minister puts ban on nonessential sexual activities of persons or greater in indoor areas coronavirus detection is possible
# --------------------------------------------------------------------------------
# Text 2
# most protection against viral particles for the wearer but other masks are effective in reducing the reach of because they help stop asymptomatic individuals from unknowingly spreading the disease news coronavirus agrees not to infect anyone while nation tries to clarify what government is advising them to do grocery milkchemist vegetable
#
# Generated
# will be open from tomorrow march introverts everywhere secretly rejoice at coronavirus excuse to isolate health coronavirus sickness introvert belgium health minister puts ban on nonessential sexual activities of persons or greater in indoor areas coronavirus detection is possible by holding your breath for seconds your story is a mixture
# --------------------------------------------------------------------------------
# Text 3
# gilead and glaxsosmithkline and their work on this problem gsk has begun codevelopment on a vaccine coronavirusoutbreak coronavirus tantrum diplomacy is eroding us credibility on the international stage withdrawing from during a global pandemic is a recipe for disaster and increases the cost of the american response we must instead rally
#
# Generated
# the world donaldtrump coronavirus russian infections florida cure quick soon you aids or cancer by the way to avoid the corona virus satbhakti is the coronavirus hoax reminds of false flag leading to syrian cruise middle strike a facebook user uploaded a video showing a man inside a police van
# --------------------------------------------------------------------------------
# Text 4
# is just like the flu so we worry about it flu vaccine increases coronavirus risk says military study the following months tiv trivalent influenza vaccine recipients had an increased risk of virologicallyconfirmed noninfluenza a increased risk ive warned about the dangers of the vaccine that will be proposed as the answer
#
# Generated
# to tell masha catfish gain of function research and fennel solution through medicine and ok the disease coronavirus is finally think thepope every fear said in march thank it is some coronavirus reports of dead in wuhan china via belgium health minister puts ban on nonessential sexual activities of persons
# --------------------------------------------------------------------------------
# Text 5
# evidence to suggest that the novel coronavirus that causes was manmade health secretary matt hancock has said houses of worship in accounting crisis over relief package donaldtrump tax coronavirus church greed the cdc can detain anyone with a fever indefinitely vaccination is a way people could get out of detention shanghai
#
# Generated
# government officially recommends vitamin c for cdc says coronavirus rna found in princess cruise ship cabins up to days after passengers left belgium health minister puts ban on nonessential sexual activities of persons or greater in indoor areas coronavirus is said of the last hours this is a cure for
# --------------------------------------------------------------------------------
# Text 6
# it biochemical saying that trump bailed out wall street but not main street got this video demoted on facebook a majority of deaths in the united states happen in a medical facility but people die at home too bill gates predicted makes announcement for criminal eugenicists perpetrating the coronavirus hoax endthelockdown
#
# Generated
# scamdemic bill gates claims that the day is a punishable offense cdc says coronavirus rna found in princess cruise ship cabins up to days after passengers left belgium health minister puts ban on nonessential sexual activities of persons or greater in indoor areas coronavirus is you have a fake race
# --------------------------------------------------------------------------------
# Text 7
# difference during the pandemic but not sure how to safely go about it collect or donate itemscertificates for our apocalypse meow auction this is an important part of our yearly fundraising to keep the abbys fund health care grants available royal palace confirms queen elizabeth tests positive for coronavirus eugenicist bill
#
# Generated
# gates cohosted a pandemic back in october just in time for the patented coronavirus he helped fund to be unleashed is a bacterium not virus olympics postponement has messed up drug cheats careful planning drugs coronavirus cheating olympicgames carrefour is offering a r voucher for families in need during coronavirus
# --------------------------------------------------------------------------------
# Text 8
# numbers american thinker has infected more meatpackers in the us than health care workers belgium health minister puts ban on nonessential sexual activities of persons or greater in indoor areas belgium health minister puts ban on nonessential sexual activities of persons or greater in indoor areas ummm this seems like it
#
# Generated
# might coronavirus just like the virus is a meeting in pune dismissing the lives to rally zealand up in also and context it coronavirus bioweapon how china stole coronavirus from canada and weaponized it via coronaviruschina may god save us from china parentodo tras leer lo siguiente hacemos una consulta
# --------------------------------------------------------------------------------
# Text 9
# left cannabis may stop coronavirus from infecting people study finds irrefutable the coronavirus was engineered by scientists in a lab using well documented genetic engineering vectors that leave behind a yournews shockerwhoa lysol kills coronavirus wha video in spanish shows can of lysol claiming to be effective on the news our
#
# Generated
# disgusting sticky tables catch and trap coronavirus safely insists wetherspoons boss amid coronavirus bill gates explains that the covid vaccine will use experimental technology and permanently alter your dna hafmay now this is a worldwide race to increase mom a higher indian caste chopped off a girls tongue as an
# --------------------------------------------------------------------------------
# Text 10
# the panic is important to who amp big pharma they need us all to panic so gladly take the they magically invent quickly to stop this invented pandemic the vaccine will spread it more the coronavirus was made in a biowarfare lab connected to gates foundation thats right baby the owners
#
# Generated
# and the union discovered a covid vaccine because matters is any cases in is the disease coronavirus is safe of a voluntary basis that would the matter of he helped fund to be done for died from this outbreak coronavirus sends to deep clean vaccine experiment facebook strain of a
# --------------------------------------------------------------------------------
